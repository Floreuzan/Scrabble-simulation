# %% [markdown]
# # Problem Set 3 Notebook

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

import ps2
import ps3a
# Out:
# Loading word list from file...
#    83667 words loaded.

# %%
def plot_mc_hand(hand, N, n):
    
    _, mc_scores = ps3a.play_n_mc_hand(hand, N, n)
    plt.figure()
    plt.hist(mc_scores, facecolor='blue', alpha=0.5)
    
    
    # naming the x axis 
    plt.xlabel('x - axis') 
    # naming the y axis 
    plt.ylabel('y - axis') 
    z='N=', str(N), 'n=', str(n)
    # giving a title to my graph 
    plt.title(z)

# %%
hand = ps2.get_frequency_dict('helloworld')
random.seed(1)
for n in (10, 100):
    for N in (1, 10, 100):
        plot_mc_hand(hand, N, n)

# %%
#Question c
#What do you notice about the maximum score and the distribution of scores for the hand as these MC parameters change?


#We can observe that for a small n, the plot shows a distribution that is discrete 
#and for n large, the plot shows a bell shape with a skew greater than 0. 

#We can interpret the result as: when n is small is follows a discrete distribution
#when n is large, the distribtion tends to a normal distribution: n is large so according to the Central Limit Theorem, 
#it is asymptotically distributed


#PS: if we had too columns for n small, we could say that it folllows a Bernoulli distribution
